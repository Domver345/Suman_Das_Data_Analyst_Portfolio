# %%
import requests
from bs4 import BeautifulSoup
import smtplib
import time
import datetime

# %%
URL= 'https://www.amazon.com/Pokemon-Gotta-Eeveelutions-Sleeve-Medium/dp/B0B6GTDMMM/ref=sr_1_15?crid=3269P8ZI62TO0&dib=eyJ2IjoiMSJ9.l_HVfz3PMv8N8jDdBUl_i9bDVUn_a27iLXZf3IXXWf-3-5JKUFF8HC-GP5c63keCKWAv4qZieQtlLrrhB7VsfFI7yV4utHg8DNniekGa5_qOGJR0s5xWv_anPQBaWMW4nZK4cMcFhavtPNYONNhpAPcZjqtwc7wXOASOYYGo605x8vrjG5aaHAdQpK7JbnZDRQgnGCPVxpXPwA66lRRAEiT4NYjUB1nrBd1a7sn0pjAszzupALRm0cM0hI_eEKmmZpoTkmBnN7OG7kPrtB3iGZj3QSRq0n43l9JJ8PkZZo.yDLrMrrV4pL094-rs6GGa_V2BhgqvqiUTCpAjnqIi9o&dib_tag=se&keywords=pokemon+tshirts+men&qid=1755505426&sprefix=pokemon+tsh%2Caps%2C468&sr=8-15'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/115.0.0.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept-Encoding": "gzip, deflate, br",
    "Referer": "https://www.amazon.com/",
    "DNT": "1",
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Dest": "document",
}



page= requests.get(URL, headers=headers)
soup1= BeautifulSoup(page.content, "html.parser")
soup2= BeautifulSoup(soup1.prettify(), "html.parser")

# %%
# Find the product details
title = soup2.find(id='productTitle').get_text()
price= soup2.find(class_="a-price a-text-price a-size-medium apexPriceToPay").get_text(strip=' ')
price= price[6:]

print(title)
print(price)
# Out:
#                   Pokémon Pokemon Gotta Catch Eeveelutions Young Men's Short Sleeve Tee Shirt
#
# $18.30

# %%
price= price.strip()[1:]
title= title.strip()

print(title)
print(price)
# Out:
# Pokémon Pokemon Gotta Catch Eeveelutions Young Men's Short Sleeve Tee Shirt
# 18.30

# %%
import datetime
today= datetime.date.today()
print(today)
# Out:
# 2025-08-21

# %%
import csv

header= ['Title', 'Price', 'Date']
data= [title, price, today]

with open('AmazonWebScrapingDataset.csv', 'w', newline='', encoding='UTF-8') as f:
  writer= csv.writer(f)
  writer.writerow(header)
  writer.writerow(data)

# %%
with open('AmazonWebScrapingDataset.csv', 'a+', newline='', encoding='UTF-8') as f:
  writer= csv.writer(f)
  writer.writerow(data)

# %%
import pandas as pd

df=pd.read_csv(r'/content/AmazonWebScrapingDataset.csv')
print(df)
# Out:
#                                                Title  Price        Date
# 0  Pokémon Pokemon Gotta Catch Eeveelutions Young...   18.3  2025-08-21
# 1  Pokémon Pokemon Gotta Catch Eeveelutions Young...   18.3  2025-08-21

# %%
def send_mail():
  server= smtplib.SMTP_SSL('smtp.gmail.com', 465)
  server.ehlo()
  server.login('sumandas211222005@gmail.com', 'uvuv@YK467:ay')

  subject= "The Eevee shirt is below 16"
  body= "You wrote this message as a test in the data analyst project"

  msg= f"Subject: {subject}\n\n {body}"

  server.sendmail(
      'sumandas21122005@gmail.com',
      msg
  )

# %%
price= float(price)
print(price)
# Out:
# 18.3

# %%
if price< 16:
  send_mail()
